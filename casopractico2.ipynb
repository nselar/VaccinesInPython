# %%
import pandas as pd
mis_datos = pd.read_csv('C:/Users/nicks/data.csv')
mis_datos = mis_datos.sort_values(['Vaccine'])
mis_datos_solo4cols = mis_datos.iloc[:,0:4]
print(mis_datos_solo4cols)
mis_datos_solo4cols.to_csv('datos_procesados.csv')
# Out:
#        YearWeekISO ReportingCountry  Denominator  NumberDosesReceived
# 0         2020-W53               AT    7388778.0                  0.0
# 244717    2022-W19               LV     261615.0                  0.0
# 244722    2022-W19               LV     102952.0                  0.0
# 71303     2021-W17               FI          NaN                  NaN
# 244726    2022-W19               LV     244986.0                  0.0
# ...            ...              ...          ...                  ...
# 198744    2022-W29               FR          NaN                  NaN
# 198743    2022-W29               FR          NaN                  NaN
# 198742    2022-W29               FR          NaN                  NaN
# 198740    2022-W29               FR      17593.0                  NaN
# 185431    2021-W01               FR          NaN                  NaN
#
# [370864 rows x 4 columns]

# %%
mis_datos.describe()
# Out:
#         Denominator  NumberDosesReceived  NumberDosesExported     FirstDose  \
# count  2.208450e+05         5.596900e+04         5.048700e+04  3.708640e+05
# mean   1.538334e+06         2.332880e+04         1.822725e+03  2.499641e+03
# std    5.253462e+06         1.968703e+05         6.515210e+04  3.214234e+04
# min    9.810000e+02         0.000000e+00         0.000000e+00  0.000000e+00
# 25%    9.731800e+04         0.000000e+00         0.000000e+00  0.000000e+00
# 50%    2.749550e+05         0.000000e+00         0.000000e+00  0.000000e+00
# 75%    1.030274e+06         0.000000e+00         0.000000e+00  3.800000e+01
# max    6.941109e+07         9.818370e+06         6.858540e+06  3.425897e+06
#
#        FirstDoseRefused    SecondDose  DoseAdditional1  DoseAdditional2  \
# count       1447.000000  3.708640e+05     3.708640e+05    370864.000000
# mean           0.401520  2.259133e+03     1.782451e+03       163.137902
# ...
